# %% [markdown]
# # Upload Modules

# %%
# Run the modules.
# %run Alzheimer_Dataset.ipynb
# %run Model_Utils.ipynb
# %run CNN_Models.ipynb

# %% [markdown]
# # Create Custom Dataset and DataLoaders

# %%
# Create train, validation and test sets.
train_dataset, validation_dataset, test_dataset = alzheimer_dataset()

# %%
# Visualize the samples from the train dataset.
visualize_dataset(train_dataset)

# %%
# Upload the datasets into PyTorch loaders.
train_loader, validation_loader, test_loader = alzheimer_dataloader()

# %%
# Visualize a batch from train dataloader.
visualize_batch(train_loader)

# %% [markdown]
# # Observe Different CNN Models

# %% [markdown]
# **CNN Model 1**

# %%
# Build the model.
cnn_model_1 = CNN_Model_1()

# %%
# Train the model.
cnn_model_1 = train_network(cnn_model_1)

# %%
# Test the model.
test_network(cnn_model_1)
# Out:
# Accuracy: 0.5811111111111111
#               precision    recall  f1-score   support
#
#            0       0.47      0.71      0.57       450
#            1       0.72      0.90      0.80       450
#            2       0.58      0.66      0.62       450
#            3       0.52      0.06      0.10       450
#
#     accuracy                           0.58      1800
#    macro avg       0.57      0.58      0.52      1800
# weighted avg       0.57      0.58      0.52      1800

# %% [markdown]
# **CNN Model 2**

# %%
# Build the model.
cnn_model_2 = CNN_Model_2()

# %%
# Train the model.
cnn_model_2 = train_network(cnn_model_2)

# %%
# Test the model.
test_network(cnn_model_2)
# Out:
# Accuracy: 0.6261111111111111
#               precision    recall  f1-score   support
#
#            0       0.60      0.52      0.55       450
#            1       0.91      0.88      0.89       450
#            2       0.59      0.69      0.64       450
#            3       0.42      0.42      0.42       450
#
#     accuracy                           0.63      1800
#    macro avg       0.63      0.63      0.63      1800
# weighted avg       0.63      0.63      0.63      1800

# %% [markdown]
# **CNN Model 3**

# %%
# Build the model.
cnn_model_3 = CNN_Model_3()

# %%
# Train the model.
cnn_model_3 = train_network(cnn_model_3)

# %%
# Test the model.
test_network(cnn_model_3)
# Out:
# Accuracy: 0.8261111111111111
#               precision    recall  f1-score   support
#
#            0       0.83      0.84      0.83       450
#            1       0.98      1.00      0.99       450
#            2       0.78      0.77      0.77       450
#            3       0.71      0.70      0.70       450
#
#     accuracy                           0.83      1800
#    macro avg       0.82      0.83      0.83      1800
# weighted avg       0.82      0.83      0.83      1800

# %% [markdown]
# **CNN Model 4**

# %%
# Build the model.
cnn_model_4 = CNN_Model_4()

# %%
# Train the model.
cnn_model_4 = train_network(cnn_model_4)

# %%
# Test the model.
test_network(cnn_model_4)
# Out:
# Accuracy: 0.6105555555555555
#               precision    recall  f1-score   support
#
#            0       0.54      0.57      0.55       450
#            1       0.78      0.93      0.84       450
#            2       0.59      0.70      0.64       450
#            3       0.45      0.24      0.31       450
#
#     accuracy                           0.61      1800
#    macro avg       0.59      0.61      0.59      1800
# weighted avg       0.59      0.61      0.59      1800

# %% [markdown]
# **CNN Model 5**

# %%
# Build the model.
cnn_model_5 = CNN_Model_5()

# %%
# Train the model.
cnn_model_5 = train_network(cnn_model_5)

# %%
# Test the model.
test_network(cnn_model_5)
# Out:
# Accuracy: 0.8122222222222222
#               precision    recall  f1-score   support
#
#            0       0.73      0.95      0.83       450
#            1       0.96      1.00      0.98       450
#            2       0.79      0.68      0.73       450
#            3       0.77      0.61      0.68       450
#
#     accuracy                           0.81      1800
#    macro avg       0.81      0.81      0.81      1800
# weighted avg       0.81      0.81      0.81      1800

# %% [markdown]
# # Save Models

# %%
torch.save(cnn_model_1, "cnn_model_1.pt")

# %%
torch.save(cnn_model_2, "cnn_model_2.pt")

# %%
torch.save(cnn_model_3, "cnn_model_3.pt")

# %%
torch.save(cnn_model_4, "cnn_model_4.pt")

# %%
torch.save(cnn_model_5, "cnn_model_5.pt")
